# %% [markdown]
# ### **Fine-Tuning Dataset**

# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("/content/Attack_Dataset.csv")

# %%
df.isnull().sum()
# Out:
# ID                          0
# Title                       0
# Category                    0
# Attack Type                 0
# Scenario Description        0
# Tools Used                 14
# Attack Steps                0
# Target Type                 4
# Vulnerability              18
# MITRE Technique            24
# Impact                      3
# Detection Method            4
# Solution                    3
# Tags                        3
# Source                    160
# Unnamed: 15             14087
# dtype: int64

# %%
df = df.drop(columns = ["Unnamed: 15"],axis = 1)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# ID                      0
# Title                   0
# Category                0
# Attack Type             0
# Scenario Description    0
# Tools Used              0
# Attack Steps            0
# Target Type             0
# Vulnerability           0
# MITRE Technique         0
# Impact                  0
# Detection Method        0
# Solution                0
# Tags                    0
# Source                  0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.head()
# Out:
#    ID                                    Title                  Category  \
# 0   1  Authentication Bypass via SQL Injection           Mobile Security
# 1   2                Union-Based SQL Injection  AI Agents & LLM Exploits
# 2   3                Error-Based SQL Injection  AI Agents & LLM Exploits
# 3   4                      Blind SQL Injection  AI Agents & LLM Exploits
# 4   5               Second-Order SQL Injection  AI Agents & LLM Exploits
#
#             Attack Type                               Scenario Description  \
# 0  SQL Injection (SQLi)  A login form fails to validate or sanitize inp...
# 1         SQL Injection  This attack occurs when a hacker uses the SQL ...
# 2         SQL Injection  This attack occurs when an attacker intentiona...
# 3         SQL Injection  In Blind SQL Injection, the attacker doesn’t s...
# 4         SQL Injection  In a Second-Order SQL Injection, the attacker ...
#
#                                           Tools Used  \
# 0                        Browser, Burp Suite, SQLMap
# 1  SQLMap, Burp Suite, Havij, Browser Developer T...
# 2  SQLMap, Burp Suite, Manual Browser Testing, Havij
# 3  SQLMap, Burp Suite, sqlninja, Manual Browser T...
# 4  Burp Suite, SQLMap, Postman, Browser Dev Tools...
#
#                                        Attack Steps   \
# 0  1. Reconnaissance: Find a login form on the we...
# 1  1. Identify User Input Points: Attacker finds ...
# 2  1. Identify Input Points:Attacker finds a fiel...
# 3  1. Find a User Input Point:Attacker finds a pl...
# 4  1. Identify Stored Input Fields:The attacker l...
#
#                                          Target Type  \
# 0  Web Login Portals (e.g., banking, admin dashbo...
# 1        Web Applications, Login Pages, Search Forms
# 2  Web Applications, Login Forms, URL Parameters,...
# 3  Web Applications, Login Pages, Search Fields, ...
# 4  Web Applications, User Registration Forms, Pro...
#
#                                        Vulnerability  \
# 0            Unsanitized input fields in SQL queries
# 1  Improperly filtered input fields that allow SQ...
# 2  Error message exposure due to lack of input va...
# 3  No error messages, but user input is still pas...
# 4  Trusting previously stored unvalidated data in...
#
#                                      MITRE Technique  \
# 0  T1078 (Valid Accounts), T1190 (Exploit Public-...
# 1          T1190 – Exploit Public-Facing Application
# 2          T1190 – Exploit Public-Facing Application
# 3          T1190 – Exploit Public-Facing Application
# 4                          T1505.003 – SQL Injection
#
#                                               Impact  \
# 0  Full account takeover, data theft, privilege e...
# 1  Data leakage, Credential theft, Account takeov...
# 2  Information disclosure, Database structure exp...
# 3  Slow and stealthy data theftFull database comp...
# 4  Delayed data theftUnexpected system behaviorSe...
#
#                                     Detection Method  \
# 0  Web server logs, anomaly detection (e.g., logi...
# 1  Web Application Firewalls (WAF)Log AnalysisInp...
# 2  Review and monitor error logsEnable generic er...
# 3  Monitor for slow and repetitive requestsAnalyz...
# 4  Log monitoring for delayed query failuresTrack...
#
#                                             Solution  \
# 0  Use prepared statements, Sanitize inputs, Limi...
# 1  Use parameterized queries (Prepared Statements...
# 2  Turn off detailed error messages in production...
# 3  Use parameterized queries (prepared statements...
# 4  Sanitize and validate inputs both at entry and...
#
#                                                 Tags  \
# 0  SQLi, Authentication Bypass, Web Security, OWA...
# 1  #SQLInjection #WebSecurity #UnionAttack #OWASP...
# 2  #SQLInjection #ErrorLeakage #WebAppSecurity #O...
# 3  #BlindSQLi #TimeBasedSQLi #WebAppSecurity #OWA...
# 4  #SecondOrderSQLi #DelayedInjection #StoredInje...
#
#                                               Source
# 0                          OWASP, MITRE ATT&CK, DVWA
# 1  OWASP, MITRE ATT&CK, Acunetix, PortSwigger Web...
# 2  OWASP, MITRE ATT&CK, Acunetix, PortSwigger Web...
# 3  OWASP, MITRE ATT&CK, Acunetix, PortSwigger, SQ...
# 4  OWASP, MITRE ATT&CK, PortSwigger Academy, Acun...

# %%
text = "Category : Mobile Security\nAttack Type : SQL Injection\nSolution : Use prepared statements"
print(text)
# Out:
# Category : Mobile Security
# Attack Type : SQL Injection
# Solution : Use prepared statements

# %%
system_prompt = """You are a SOC analyst.
Read the title of the Attack provided. Based on the Attack Type provide the description of scenario,
The associated MITRE Technique. Also provide for each title associated Category of attack, type of attack.
Once done provide the best solution or action to take"""

# %%
file = open("Fine_Tune_Attack_Dataset.jsonl","w")
for _,row in df.iterrows() :
  data = {
      "messages" : [
          {"role" : "system","content" : system_prompt},
          {"role" : "user","content" : str(row["Title"])},
          {"role" : "assistant","content" : "Category : " + str(row["Category"]) + "\nAttack Type : " + str(row["Attack Type"]) + "\nSolution : " + str(row["Solution"])}
      ]
  }
  file.write(json.dumps(data) + "\n")
file.close()

# %%
df = pd.read_json("/content/Fine_Tune_Attack_Dataset.jsonl",lines = True)

# %%
df.head()
# Out:
#                                             messages
# 0  [{'role': 'system', 'content': 'You are a SOC ...
# 1  [{'role': 'system', 'content': 'You are a SOC ...
# 2  [{'role': 'system', 'content': 'You are a SOC ...
# 3  [{'role': 'system', 'content': 'You are a SOC ...
# 4  [{'role': 'system', 'content': 'You are a SOC ...

# %%
from sklearn.model_selection import train_test_split
df_train,df_val = train_test_split(df,test_size = 0.2,
                                               random_state = 42)
print(df_train.shape)
print(df_val.shape)
# Out:
# (11141, 1)
# (2786, 1)

# %%
df_train.to_json("Fine_Tune_GPT_Train.jsonl",orient = "records",
                 lines = True)
df_val.to_json("Fine_Tune_GPT_Test.jsonl",orient = "records",
                 lines = True)

# %% [markdown]
# ### **Fine Tuning Job**

# %%
from openai import OpenAI
from google.colab import userdata

# Load the API key securely from Colab secrets
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
client = OpenAI(api_key = OPENAI_API_KEY)
client.files.create(
    file = open("/content/Fine_Tune_GPT_Train.jsonl","rb"),
    purpose = "fine-tune"
)
# Out:
# FileObject(id='file-T1Kg6bFKaWeF4L6257NmoQ', bytes=6631837, created_at=1763140419, filename='Fine_Tune_GPT_Train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
client.files.create(
    file = open("/content/Fine_Tune_GPT_Test.jsonl","rb"),
    purpose = "fine-tune"
)
# Out:
# FileObject(id='file-LkTQi8cGGs2HbAVE74sfmv', bytes=1659342, created_at=1763140482, filename='Fine_Tune_GPT_Test.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
client.fine_tuning.jobs.create(
    model = "gpt-4o-mini-2024-07-18",
    training_file = "file-T1Kg6bFKaWeF4L6257NmoQ",
    validation_file = "file-LkTQi8cGGs2HbAVE74sfmv",
    hyperparameters = {"n_epochs" : 3}
)
# Out:
# FineTuningJob(id='ftjob-5rnXVbxJiziAh4YP0kpS9yk3', created_at=1763140613, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=3), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-1ASoeatyKpzdP7XUIEeN3alQ', result_files=[], seed=169862197, status='validating_files', trained_tokens=None, training_file='file-T1Kg6bFKaWeF4L6257NmoQ', validation_file='file-LkTQi8cGGs2HbAVE74sfmv', estimated_finish=None, integrations=[], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=3))), user_provided_suffix=None, usage_metrics=None, shared_with_openai=False, eval_id=None)

# %% [markdown]
# ### **Using the Fine - Tuned Model**

# %%
from openai import OpenAI

# %%
system_prompt = """You are a SOC analyst.
Read the title of the Attack provided. Based on the Attack Type provide the description of scenario,
The associated MITRE Technique. Also provide for each title associated Category of attack, type of attack.
Once done provide the best solution or action to take"""

# %%
client = OpenAI(api_key = OPENAI_API_KEY)
response = client.responses.create(
    model = "ft:gpt-4o-mini-2024-07-18:shoeb-sutar::CbsZknC6",
    input = [
        {"role" : "system","content" : system_prompt},
        {"role" : "user","content" : "Clickjacking with Popups (Window Redressing)"}
    ]
)
print(response.output_text)
# Out:
# Category : Web Application Security
# Attack Type : Clickjacking / UI Redressing
# Solution : Use X-Frame-Options; block popups in modern UI workflow

# %% [markdown]
# ### **Evaluating Fine Tuned Model**

# %%
import pandas as pd
import numpy as np
from openai import OpenAI

# %%
df = pd.read_csv("/content/Attack_Dataset.csv")

# %%
print(df.isnull().sum())
# Out:
# ID                          0
# Title                       0
# Category                    0
# Attack Type                 0
# Scenario Description        0
# Tools Used                 14
# Attack Steps                0
# Target Type                 4
# Vulnerability              18
# MITRE Technique            24
# Impact                      3
# Detection Method            4
# Solution                    3
# Tags                        3
# Source                    160
# Unnamed: 15             14087
# dtype: int64

# %%
df = df.drop(columns = ["Unnamed: 15"],axis = 1)

# %%
df = df.dropna()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.head()
# Out:
#    ID                                    Title                  Category  \
# 0   1  Authentication Bypass via SQL Injection           Mobile Security
# 1   2                Union-Based SQL Injection  AI Agents & LLM Exploits
# 2   3                Error-Based SQL Injection  AI Agents & LLM Exploits
# 3   4                      Blind SQL Injection  AI Agents & LLM Exploits
# 4   5               Second-Order SQL Injection  AI Agents & LLM Exploits
#
#             Attack Type                               Scenario Description  \
# 0  SQL Injection (SQLi)  A login form fails to validate or sanitize inp...
# 1         SQL Injection  This attack occurs when a hacker uses the SQL ...
# 2         SQL Injection  This attack occurs when an attacker intentiona...
# 3         SQL Injection  In Blind SQL Injection, the attacker doesn’t s...
# 4         SQL Injection  In a Second-Order SQL Injection, the attacker ...
#
#                                           Tools Used  \
# 0                        Browser, Burp Suite, SQLMap
# 1  SQLMap, Burp Suite, Havij, Browser Developer T...
# 2  SQLMap, Burp Suite, Manual Browser Testing, Havij
# 3  SQLMap, Burp Suite, sqlninja, Manual Browser T...
# 4  Burp Suite, SQLMap, Postman, Browser Dev Tools...
#
#                                        Attack Steps   \
# 0  1. Reconnaissance: Find a login form on the we...
# 1  1. Identify User Input Points: Attacker finds ...
# 2  1. Identify Input Points:Attacker finds a fiel...
# 3  1. Find a User Input Point:Attacker finds a pl...
# 4  1. Identify Stored Input Fields:The attacker l...
#
#                                          Target Type  \
# 0  Web Login Portals (e.g., banking, admin dashbo...
# 1        Web Applications, Login Pages, Search Forms
# 2  Web Applications, Login Forms, URL Parameters,...
# 3  Web Applications, Login Pages, Search Fields, ...
# 4  Web Applications, User Registration Forms, Pro...
#
#                                        Vulnerability  \
# 0            Unsanitized input fields in SQL queries
# 1  Improperly filtered input fields that allow SQ...
# 2  Error message exposure due to lack of input va...
# 3  No error messages, but user input is still pas...
# 4  Trusting previously stored unvalidated data in...
#
#                                      MITRE Technique  \
# 0  T1078 (Valid Accounts), T1190 (Exploit Public-...
# 1          T1190 – Exploit Public-Facing Application
# 2          T1190 – Exploit Public-Facing Application
# 3          T1190 – Exploit Public-Facing Application
# 4                          T1505.003 – SQL Injection
#
#                                               Impact  \
# 0  Full account takeover, data theft, privilege e...
# 1  Data leakage, Credential theft, Account takeov...
# 2  Information disclosure, Database structure exp...
# 3  Slow and stealthy data theftFull database comp...
# 4  Delayed data theftUnexpected system behaviorSe...
#
#                                     Detection Method  \
# 0  Web server logs, anomaly detection (e.g., logi...
# 1  Web Application Firewalls (WAF)Log AnalysisInp...
# 2  Review and monitor error logsEnable generic er...
# 3  Monitor for slow and repetitive requestsAnalyz...
# 4  Log monitoring for delayed query failuresTrack...
#
#                                             Solution  \
# 0  Use prepared statements, Sanitize inputs, Limi...
# 1  Use parameterized queries (Prepared Statements...
# 2  Turn off detailed error messages in production...
# 3  Use parameterized queries (prepared statements...
# 4  Sanitize and validate inputs both at entry and...
#
#                                                 Tags  \
# 0  SQLi, Authentication Bypass, Web Security, OWA...
# 1  #SQLInjection #WebSecurity #UnionAttack #OWASP...
# 2  #SQLInjection #ErrorLeakage #WebAppSecurity #O...
# 3  #BlindSQLi #TimeBasedSQLi #WebAppSecurity #OWA...
# 4  #SecondOrderSQLi #DelayedInjection #StoredInje...
#
#                                               Source
# 0                          OWASP, MITRE ATT&CK, DVWA
# 1  OWASP, MITRE ATT&CK, Acunetix, PortSwigger Web...
# 2  OWASP, MITRE ATT&CK, Acunetix, PortSwigger Web...
# 3  OWASP, MITRE ATT&CK, Acunetix, PortSwigger, SQ...
# 4  OWASP, MITRE ATT&CK, PortSwigger Academy, Acun...

# %%
df_eval = df.sample(n = 100,random_state = 42)

# %%
df_eval.head()
# Out:
#           ID                                         Title  \
# 13195  13196                     Spoof Engine RPM Readings
# 3085    3086            SSRF via LFI + Wrapper (expect://)
# 12309  12310             WMI Persistence via Event Filters
# 12719  12720  Seed Corpus Curation for HTML5 Video Players
# 2105    2106             Auto-Login to Phishing OAuth URLs
#
#                                                 Category  \
# 13195  Automotive / Cyber-Physical Systems → CAN Bus ...
# 3085                            Web Application Security
# 12309                                               DFIR
# 12719                        Zero-Day Research / Fuzzing
# 2105                                     Mobile Security
#
#                                              Attack Type  \
# 13195                                           Spoofing
# 3085   Local File Inclusion + Remote Code Execution v...
# 12309                                        Persistence
# 12719                               Fuzzer Configuration
# 2105          Agent follows OAuth flow to malicious site
#
#                                     Scenario Description  \
# 13195  An attacker injects fake engine RPM messages t...
# 3085   Uses expect:// wrapper to execute commands whe...
# 12309  Attacker creates a WMI subscription that execu...
# 12719  Collecting and preparing valid HTML5 video fil...
# 2105   An attacker injects a fake OAuth URL into the ...
#
#                                     Tools Used  \
# 13195             ICSim, SocketCAN, Python-CAN
# 3085               Burp Suite, PHP interpreter
# 12309             WMI Command-line, PowerShell
# 12719                         AFL++, libFuzzer
# 2105   Burp Suite, Fake OAuth server, Chat App
#
#                                            Attack Steps   \
# 13195  1. Tap into vehicle’s CAN bus using USB2CAN ad...
# 3085   Step 1: Find an LFI (Local File Inclusion) or ...
# 12309  1. Uses command-line or PowerShell to register...
# 12719  1. Identify target HTML5 video player componen...
# 2105   Step 1: Identify a mobile app or chatbot that ...
#
#                            Target Type  \
# 13195                    Dashboard ECU
# 3085   PHP apps using dynamic includes
# 12309                Enterprise System
# 12719              Multimedia browsers
# 2105           AI Chatbots, OAuth Apps
#
#                                            Vulnerability  \
# 13195             No message authentication between ECUs
# 3085          LFI with wrapper abuse (command execution)
# 12309                               Lack of WMI auditing
# 12719                 Buffer overflow, memory corruption
# 2105   No link validation; unsafe OAuth redirect hand...
#
#                                          MITRE Technique  \
# 13195                                              T1642
# 3085                           T1059 – Command Execution
# 12309  T1546.003 – Event Triggered Execution: WMI Eve...
# 12719                                              T1201
# 2105                    T1557.003 – OAuth Redirect Abuse
#
#                                               Impact  \
# 13195                Driver deception or distraction
# 3085            Full Remote Code Execution (via LFI)
# 12309                  Long-term stealth persistence
# 12719  Discovery of crashes or remote code execution
# 2105              Credential theft, account takeover
#
#                                         Detection Method  \
# 13195        Compare real sensor output with bus traffic
# 3085   Log file reads from unexpected wrappers; audit...
# 12309          WMI logs, Autoruns, KAPE registry modules
# 12719                        Fuzzer logs, crash analysis
# 2105   Monitor outbound OAuth redirects; validate all...
#
#                                                 Solution  \
# 13195                       Message signing between ECUs
# 3085   Disable PHP wrappers like expect://; sanitize ...
# 12309  Monitor WMI namespaces, use WMI Explorer for f...
# 12719     Patch multimedia parsing code, validate inputs
# 2105   Whitelist OAuth providers; validate OAuth link...
#
#                                                 Tags  \
# 13195                 spoofing, RPM, CAN, automotive
# 3085      LFI to RCE, PHP Wrapper, expect:// Exploit
# 12309              stealthy persistence, WMI trigger
# 12719  fuzzing, seed corpus, multimedia, HTML5 video
# 2105      OAuth Phishing, Auto-Login, Redirect Abuse
#
#                               Source
# 13195  Real-world CAN injection test
# 3085               Exploit-DB, OWASP
# 12309            Real-world IR cases
# 12719  https://www.w3.org/TR/html52/
# 2105            Evilginx, OWASP Labs

# %%
eval_input = df_eval["Title"].tolist()
references = df_eval["Solution"].tolist()

# %%
len(eval_input)
# Out:
# 100

# %%
system_prompt = """You are a SOC analyst.
Read the title of the Attack provided. Based on the Attack Type provide ONLY provide detailed solution or action to take aginst it
without any fancy title or bold text, simple in the form of simple python string, Do not include any double quotation at beginning or end"""

# %%
client = OpenAI(api_key = OPENAI_API_KEY)
def predict (prompt) :
  response = client.responses.create(
      model = "ft:gpt-4o-mini-2024-07-18:shoeb-sutar::CbsZknC6",
      input = [
          {"role" : "system","content" : system_prompt},
          {"role" : "user","content" : prompt}
      ]
  )
  return str(response.output_text)

# %%
hypothesis = [predict(x) for x in eval_input]
hypothesis

# %% [markdown]
# #### **BLEU Score**

# %%
# !pip install sacrebleu

# %%
import sacrebleu
references_single = [[r] for r in references]
# corpus BLEU:
score = sacrebleu.corpus_bleu(hypothesis, [references])
print("BLEU (corpus):", score.score)
# Out:
# BLEU (corpus): 0.9042132302660617

# %% [markdown]
# #### **ROUGE Score**

# %%
# !pip install evaluate

# %%
# !pip install rouge_score

# %%
import evaluate
rouge = evaluate.load('rouge')
res = rouge.compute(predictions = hypothesis,
                    references = references)
print(res)
# Out:
# {'rouge1': np.float64(0.17157806881742296), 'rouge2': np.float64(0.018743130966414723), 'rougeL': np.float64(0.14709432545671658), 'rougeLsum': np.float64(0.1462477540837314)}

# %% [markdown]
# #### **Accuracy**

# %%
system_prompt = """You are a SOC analyst.
Read the title of the Attack provided. Based on the Attack Type provide ONLY provide Attack Type out of the 84 types only learnt during training
without any fancy title or bold text, simple in the form of simple python string, Do not include any double quotation at beginning or end"""

# %%
def attack_type (prompt) :
  response = client.responses.create(
      model = "ft:gpt-4o-mini-2024-07-18:shoeb-sutar::CbsZknC6",
      input = [
          {"role" : "system","content" : system_prompt},
          {"role" : "user","content" : prompt}
      ]
  )
  return str(response.output_text)

# %%
actual_attack = df_eval["Attack Type"].tolist()
prdt_attack = [attack_type(x) for x in actual_attack]
prdt_attack

# %%
n = 100
count = 0
for x,y in zip(prdt_attack,actual_attack) :
  if x.lower() == y.lower() :
    count = count + 1

acc = (count / n)
print("The Accuracy of Model is : ",acc)
# Out:
# The Accuracy of Model is :  0.0

# %% [markdown]
# ### **Screen Shots**

# %%
system_prompt = """You are a SOC analyst.
Read the title of the Attack provided. Based on the Attack Type provide the description of scenario,
The associated MITRE Technique. Also provide for each title associated Category of attack, type of attack.
Once done provide the detailed best solution or action to take in simple language and 2 to 3 lines"""

# %%
{"messages": [
   {"role": "system", "content": "SYSTEM_PROMPT"},
   {"role": "user", "content": "<TITLE/INCIDENT DESCRIPTION>"},
   {"role": "assistant", "content": "<CATEGORY / ATTACK TYPE / SOLUTION>"}
]}

# %%
from openai import OpenAI
client = OpenAI()

client.fine_tuning.jobs.create (
    model = "gpt-4o-mini-2024-07-18",
    training_file = "file-training-id",
    validation_file = "file-validation-id",
    hyperparameters = {"n_epochs": 3}
)

# %%
response = client.responses.create (
   model = "ft:gpt-4o-mini:<custom-id>",
   input = "Investigate unusual outbound traffic detected on port 4444."
)
print(response.output_text)

# %%
prompt = "This attack abuses the browser’s ability to load external resources like <script> or <link> to trigger unintended GET/POST requests to a target server from a different domain. Because browsers automatically send cookies with these requests, attackers can exploit this to perform unauthorized actions without needing JavaScript execution."

# %%
client = OpenAI(api_key = OPENAI_API_KEY)
response = client.responses.create(
    model = "ft:gpt-4o-mini-2024-07-18:shoeb-sutar::CbsZknC6",
    input = [
        {"role" : "system","content" : system_prompt},
        {"role" : "user","content" : prompt}
    ]
)
print(response.output_text)
# Out:
# Category : Web Application Security
# Attack Type : DOM Injection (Stored/Reflected)
# Solution : SameSite cookies, CSRF protection for all state-changing actions
